# %% [markdown]
# # EchoNet-Dynamic Exploratory Data Analysis
# Analyzing echocardiogram videos, EF distribution, and segmentation tracings.

# %%
import sys; sys.path.insert(0, '..')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from src.config import RAW_DIR, FILE_LIST, VOLUME_TRACINGS

# %%
df = pd.read_csv(FILE_LIST)
df.head()

# %%
print(f'Total videos: {len(df)}')
print(f'Train: {(df.Split == "TRAIN").sum()}')
print(f'Val:   {(df.Split == "VAL").sum()}')
print(f'Test:  {(df.Split == "TEST").sum()}')
df.EF.hist(bins=80)
plt.title('EF Distribution')
plt.show()

# %%
tracings = pd.read_csv(VOLUME_TRACINGS)
tracings.head()

# %%
print(f'Total tracings: {len(tracings)}')
print(f'Unique videos: {tracings.FileName.nunique()}')
print(f'Points per tracing: {tracings.groupby(["FileName","Frame"]).size().value_counts()}')
